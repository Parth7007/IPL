# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from xgboost import XGBRegressor
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import joblib

# Load processed data
df = pd.read_csv('ipl_cleaned.csv')

# If encoded columns aren't present, encode them now

# %%
df.head()
# Out:
#    Unnamed: 0         batting_team     bowling_team         venue  inning  \
# 0           0  Chennai Super Kings  Deccan Chargers  Buffalo Park       1
# 1           1  Chennai Super Kings  Deccan Chargers  Buffalo Park       1
# 2           2  Chennai Super Kings  Deccan Chargers  Buffalo Park       1
# 3           3  Chennai Super Kings  Deccan Chargers  Buffalo Park       1
# 4           4  Chennai Super Kings  Deccan Chargers  Buffalo Park       1
#
#    over  ball  balls_bowled  runs_total wicket_kind  ...  current_wickets  \
# 0     0     1             1           0        none  ...                0
# 1     0     2             2           1        none  ...                0
# 2     0     3             3           0        none  ...                0
# 3     0     4             4           4        none  ...                0
# 4     0     5             5           1        none  ...                0
#
#    final_score  batting_team_encoded  bowling_team_encoded  venue_encoded  \
# 0          178                     0                     1              7
# 1          178                     0                     1              7
# 2          178                     0                     1              7
# 3          178                     0                     1              7
# 4          178                     0                     1              7
#
#    balls_remaining  current_run_rate  team_avg_score  bowling_avg_conceded  \
# 0              119               0.0      339.446175            248.929749
# 1              118               3.0      339.446175            248.929749
# 2              117               2.0      339.446175            248.929749
# 3              116               7.5      339.446175            248.929749
# 4              115               7.2      339.446175            248.929749
#
#    venue_avg_score
# 0       134.767832
# 1       134.767832
# 2       134.767832
# 3       134.767832
# 4       134.767832
#
# [5 rows x 21 columns]
